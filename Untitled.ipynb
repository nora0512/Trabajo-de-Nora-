# %%
### Ejercicio 2 - Crea una celda markdown con el título del cuaderno (1 pto)

# Título del Cuaderno de Ciencia de Datos


### Ejercicio 3 - Crea una celda markdown para una introducción (1 pto)

## Introducción

Este cuaderno está diseñado para explorar conceptos fundamentales en la Ciencia de Datos, incluyendo lenguajes de programación, bibliotecas y herramientas esenciales. 


### Ejercicio 4 - Crea una celda markdown para enumerar los lenguajes de la ciencia de datos (3 ptos)

## Lenguajes de la Ciencia de Datos
1. Python
2. R
3. SQL
4. Java
5. Scala
6. Julia


### Ejercicio 5 - Crea una celda markdown para listar bibliotecas de ciencia de datos (3 ptos)

## Bibliotecas de Ciencia de Datos
1. Pandas
2. NumPy
3. Matplotlib
4. Seaborn
5. Scikit-learn
6. TensorFlow
7. PyTorch


### Ejercicio 6 - Crea una celda markdown con una tabla de herramientas de Ciencia de Datos (3 ptos)

## Herramientas de Ciencia de Datos

| Herramienta       | Descripción                          |
|-------------------|--------------------------------------|
| Jupyter Notebook   | Entorno interactivo para Python      |
| RStudio           | Entorno de desarrollo para R         |
| Apache Spark      | Procesamiento de grandes datos       |
| Tableau           | Visualización de datos               |
| Git               | Control de versiones                 |


### Ejercicio 7 - Crea una celda markdown introduciendo ejemplos de expresiones aritméticas (1 pto)

## Ejemplos de Expresiones Aritméticas
1. Suma: `a + b`
2. Resta: `a - b`
3. Multiplicación: `a * b`
4. División: `a / b`


### Ejercicio 8 - Crea una celda de código para multiplicar y sumar números (2 ptos)

# Código para multiplicar y sumar números
a = 5
b = 10

multiplicacion = a * b
suma = a + b

multiplicacion, suma


### Ejercicio 9 - Crea una celda de código para convertir minutos en horas (2 ptos)

# Código para convertir minutos en horas
def convertir_minutos_a_horas(minutos):
    horas = minutos / 60
    return horas

# Ejemplo de uso
convertir_minutos_a_horas(120)


### Ejercicio 10 - Inserte una celda de código para listar Objetivos (3 ptos)

# Listar Objetivos
objetivos = [
    "Entender los conceptos básicos de la ciencia de datos.",
    "Familiarizarse con lenguajes y bibliotecas.",
    "Aplicar técnicas de análisis de datos."
]

for objetivo in objetivos:
    print(objetivo)


### Ejercicio 11 - Crea una celda markdown para indicar el nombre del Autor (2 ptos)

## Autor
Nombre del Autor: [Nora]
